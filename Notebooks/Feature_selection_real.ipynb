# %% [markdown]
# # **BUSINESS CASE 2: SIEMENS ADVANTA SALES FORECASTING**
#
#
# ## 🎓 Master’s Program in Data Science & Advanced Analytics
# **Nova IMS** | March 2025
# **Course:** Business Cases with Data Science
#
# ## 👥 Team **Group A**
# - **Alice Viegas** | 20240572
# - **Bernardo Faria** | 20240579
# - **Dinis Pinto** | 20240612
# - **Daan van Holten** | 20240681
# - **Philippe Dutranoit** | 20240518

# %% [markdown]
# ## 📊 Goal of the notebook
#
# this notebook focuses on feature selection

# %% [markdown]
#  ## 1. Initial setup and modules/packages loading

# %%
# Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler

from Functions import *

from Feature_selection_Functions import (
    plot_cross_correlation,
    select_features_decision_tree,
)


import importlib
imported_module = importlib.import_module("Feature_selection_Functions")
importlib.reload(imported_module)
# Out:
# <module 'Feature_selection_Functions' from '/Users/philippedutranoit/document_ordi/nova/business_case_for_data_sciense/cases/BC_DA_Siemens/Notebooks/Feature_selection_Functions.py'>

# %%
#!pip install openpyxl

# %% [markdown]
# # Importing Data

# %%
df_market = pd.read_csv("../Data/df_market.csv")
info_market = pd.read_csv("../Data/info_market.csv")

sales_agg1 = pd.read_csv("../Data/sales_agg1.csv")
sales_agg3 = pd.read_csv("../Data/sales_agg3.csv")
sales_agg4 = pd.read_csv("../Data/sales_agg4.csv")
sales_agg5 = pd.read_csv("../Data/sales_agg5.csv")
sales_agg6 = pd.read_csv("../Data/sales_agg6.csv")
sales_agg8 = pd.read_csv("../Data/sales_agg8.csv")
sales_agg9 = pd.read_csv("../Data/sales_agg9.csv")
sales_agg11 = pd.read_csv("../Data/sales_agg11.csv")
sales_agg12 = pd.read_csv("../Data/sales_agg12.csv")
sales_agg13 = pd.read_csv("../Data/sales_agg13.csv")
sales_agg14 = pd.read_csv("../Data/sales_agg14.csv")
sales_agg16 = pd.read_csv("../Data/sales_agg16.csv")
sales_agg20 = pd.read_csv("../Data/sales_agg20.csv")
sales_agg36 = pd.read_csv("../Data/sales_agg36.csv")

# %% [markdown]
# # Product Group Analysis

# %% [markdown]
# # Product Group 1

# %% [markdown]
# ## feature selection

# %%
relevant_corr_1, selected_features_1 = plot_cross_correlation(
    sales_df=sales_agg1,
    market_df=df_market,
    product_group=1,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO156', 'MAB_ELE_SHP156']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_1)]

filtered_info_market
# Out:
#   Region                                Index Name      Index Code
# 0  China  Production Index Machinery & Electricals  MAB_ELE_PRO156
# 1  China   Shipments Index Machinery & Electricals  MAB_ELE_SHP156

# %%
selected_dt_features_1 = select_features_decision_tree(
    sales_df=sales_agg1,
    market_df=df_market,
    product_group=1,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 1:
# MAB_ELE_PRO276        0.694482
# MAB_ELE_SHP1100       0.163333
# MAB_ELE_SHP380        0.055550
# PRO27826_org          0.042230
# RohiNATGAS1000_org    0.023523
# PRO28380_org          0.019633
# dtype: float64

# %% [markdown]
# # Product Group 3

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_3, selected_features_3 = plot_cross_correlation(
    sales_df=sales_agg3,
    market_df=df_market,
    product_group=3,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['PRO28840_org']

# %% [markdown]
# ### Autocorrelation

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_3)]

filtered_info_market
# Out:
#            Region                      Index Name    Index Code
# 31  United States  Machinery and equipment n.e.c.  PRO28840_org

# %%
selected_dt_features_3 = select_features_decision_tree(
    sales_df=sales_agg3,
    market_df=df_market,
    product_group=3,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 3:
# WKLWEUR840_org        0.328907
# PRO27826_org          0.320849
# RohiNATGAS1000_org    0.140886
# PRI27380_org          0.096339
# PRI27156_org          0.065501
# MAB_ELE_SHP156        0.047519
# dtype: float64

# %% [markdown]
# # Product Group 4

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_4, selected_features_4 = plot_cross_correlation(
    sales_df=sales_agg4,
    market_df=df_market,
    product_group=4,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['WKLWEUR840_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_4)]

filtered_info_market
# Out:
#            Region  Index Name      Index Code
# 24  United States  EUR in LCU  WKLWEUR840_org

# %% [markdown]
# # Product Group 5

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_5, selected_features_5 = plot_cross_correlation(
    sales_df=sales_agg5,
    market_df=df_market,
    product_group=5,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO250', 'MAB_ELE_SHP250', 'MAB_ELE_PRO276', 'MAB_ELE_SHP276', 'MAB_ELE_SHP1100', 'PRO28250_org', 'PRO28276_org', 'PRO27392_org']

# %% [markdown]
# ### Auto correlation

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_5)]

filtered_info_market
# Out:
#      Region                                Index Name       Index Code
# 2    France  Production Index Machinery & Electricals   MAB_ELE_PRO250
# 3    France   Shipments Index Machinery & Electricals   MAB_ELE_SHP250
# 4   Germany  Production Index Machinery & Electricals   MAB_ELE_PRO276
# 5   Germany   Shipments Index Machinery & Electricals   MAB_ELE_SHP276
# 17   Europe   Shipments Index Machinery & Electricals  MAB_ELE_SHP1100
# 37   France            Machinery and equipment n.e.c.     PRO28250_org
# 38  Germany            Machinery and equipment n.e.c.     PRO28276_org
# 44    Japan                      Electrical equipment     PRO27392_org

# %%
selected_dt_features_5 = select_features_decision_tree(
    sales_df=sales_agg5,
    market_df=df_market,
    product_group=5,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 5:
# PRO27826_org          0.264080
# WKLWEUR840_org        0.189721
# PRO27392_org          0.162423
# MAB_ELE_SHP250        0.154573
# RohiNATGAS1000_org    0.138578
# MAB_ELE_SHP756        0.063979
# MAB_ELE_PRO840        0.021794
# dtype: float64

# %% [markdown]
# # Product Group 6

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ### Correlation

# %%
relevant_corr_6, selected_features_6 = plot_cross_correlation(
    sales_df=sales_agg6,
    market_df=df_market,
    product_group=6,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_SHP380']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_6)]

filtered_info_market
# Out:
#   Region                               Index Name      Index Code
# 7  Italy  Shipments Index Machinery & Electricals  MAB_ELE_SHP380

# %%
selected_dt_features_6 = select_features_decision_tree(
    sales_df=sales_agg6,
    market_df=df_market,
    product_group=6,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 6:
# PRO27276_org      0.427142
# PRO28276_org      0.239670
# PRO28380_org      0.147846
# PRO27840_org      0.134655
# PRO27392_org      0.020759
# MAB_ELE_PRO840    0.016861
# dtype: float64

# %% [markdown]
# # Product Group 8

# %% [markdown]
# ## Feature seletion

# %%
relevant_corr_8, selected_features_8 = plot_cross_correlation(
    sales_df=sales_agg8,
    market_df=df_market,
    product_group=8,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO156', 'MAB_ELE_SHP156', 'MAB_ELE_PRO756', 'MAB_ELE_SHP840', 'RohiBASEMET1000_org', 'RohiENERGY1000_org', 'RohiMETMIN1000_org', 'RohiNATGAS1000_org', 'RohCRUDE_PETRO1000_org', 'RohCOPPER1000_org', 'WKLWEUR840_org', 'PRI27840_org', 'PRI27826_org', 'PRI27380_org', 'PRI27250_org', 'PRI27276_org', 'PRI27156_org', 'PRO281000_org', 'PRO28756_org', 'PRO271000_org', 'PRO27756_org']

# %% [markdown]
# ### Auto correlation

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_8)]

filtered_info_market
# Out:
#             Region                                Index Name  \
# 0            China  Production Index Machinery & Electricals
# 1            China   Shipments Index Machinery & Electricals
# 10     Switzerland  Production Index Machinery & Electricals
# 15   United States   Shipments Index Machinery & Electricals
# 18           World                      Price of Base Metals
# 19           World                           Price of Energy
# 20           World               Price of Metals  & Minerals
# 21           World                Price of Natural gas index
# 22           World               Price of Crude oil, average
# 23           World                           Price of Copper
# 24   United States                                EUR in LCU
# 25   United States                      Electrical equipment
# 26  United Kingdom                      Electrical equipment
# 27           Italy                      Electrical equipment
# 28          France                      Electrical equipment
# 29         Germany                      Electrical equipment
# 30           China                      Electrical equipment
# 32           World            Machinery and equipment n.e.c.
# 33     Switzerland            Machinery and equipment n.e.c.
# 40           World                      Electrical equipment
# 41     Switzerland                      Electrical equipment
#
#                 Index Code
# 0           MAB_ELE_PRO156
# 1           MAB_ELE_SHP156
# 10          MAB_ELE_PRO756
# 15          MAB_ELE_SHP840
# 18     RohiBASEMET1000_org
# 19      RohiENERGY1000_org
# 20      RohiMETMIN1000_org
# 21      RohiNATGAS1000_org
# 22  RohCRUDE_PETRO1000_org
# 23       RohCOPPER1000_org
# 24          WKLWEUR840_org
# 25            PRI27840_org
# 26            PRI27826_org
# 27            PRI27380_org
# 28            PRI27250_org
# 29            PRI27276_org
# 30            PRI27156_org
# 32           PRO281000_org
# 33            PRO28756_org
# 40           PRO271000_org
# 41            PRO27756_org

# %%
selected_dt_features_8_diff = select_features_decision_tree(
    sales_df=sales_agg8,
    market_df=df_market,
    product_group=8,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 8:
# PRI27840_org              0.490918
# MAB_ELE_SHP276            0.181642
# PRO27826_org              0.098927
# MAB_ELE_SHP156            0.065707
# PRO27840_org              0.064182
# RohiMETMIN1000_org        0.044698
# RohCRUDE_PETRO1000_org    0.025761
# MAB_ELE_SHP250            0.012933
# dtype: float64

# %% [markdown]
# # Product Group 9

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_9, selected_features_9 = plot_cross_correlation(
    sales_df=sales_agg9,
    market_df=df_market,
    product_group=9,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# []

# %% [markdown]
# ### Auto correlation

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_9)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %%
selected_dt_features_9 = select_features_decision_tree(
    sales_df=sales_agg9,
    market_df=df_market,
    product_group=9,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 9:
# PRO27756_org       0.492979
# PRO27392_org       0.222231
# MAB_ELE_SHP276     0.109935
# MAB_ELE_SHP1100    0.108770
# MAB_ELE_PRO156     0.066085
# dtype: float64

# %% [markdown]
# # Product Group 11

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_11, selected_features_11 = plot_cross_correlation(
    sales_df=sales_agg11,
    market_df=df_market,
    product_group=11,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO392', 'MAB_ELE_SHP392', 'PRO28392_org', 'PRO28250_org', 'PRO27826_org', 'PRO27392_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_11)]

filtered_info_market
# Out:
#             Region                                Index Name      Index Code
# 8            Japan  Production Index Machinery & Electricals  MAB_ELE_PRO392
# 9            Japan   Shipments Index Machinery & Electricals  MAB_ELE_SHP392
# 36           Japan            Machinery and equipment n.e.c.    PRO28392_org
# 37          France            Machinery and equipment n.e.c.    PRO28250_org
# 42  United Kingdom                      Electrical equipment    PRO27826_org
# 44           Japan                      Electrical equipment    PRO27392_org

# %%
selected_dt_features_11 = select_features_decision_tree(
    sales_df=sales_agg11,
    market_df=df_market,
    product_group=11,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 11:
# PRO27826_org          0.279821
# PRI27826_org          0.163463
# MAB_ELE_SHP380        0.120747
# MAB_ELE_PRO156        0.117387
# MAB_ELE_PRO1100       0.115487
# PRO28392_org          0.115161
# RohiNATGAS1000_org    0.071749
# dtype: float64

# %% [markdown]
# # Product Group 12

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_12, selected_features_12 = plot_cross_correlation(
    sales_df=sales_agg12,
    market_df=df_market,
    product_group=12,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO156', 'MAB_ELE_SHP156', 'MAB_ELE_PRO756', 'MAB_ELE_SHP756', 'MAB_ELE_SHP826', 'MAB_ELE_SHP840', 'RohiBASEMET1000_org', 'RohiMETMIN1000_org', 'RohCOPPER1000_org', 'WKLWEUR840_org', 'PRI27840_org', 'PRI27826_org', 'PRI27250_org', 'PRI27276_org', 'PRO28756_org', 'PRO271000_org', 'PRO27756_org']

# %% [markdown]
# ### Auto correlation

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_12)]

filtered_info_market
# Out:
#             Region                                Index Name  \
# 0            China  Production Index Machinery & Electricals
# 1            China   Shipments Index Machinery & Electricals
# 10     Switzerland  Production Index Machinery & Electricals
# 11     Switzerland   Shipments Index Machinery & Electricals
# 13  United Kingdom   Shipments Index Machinery & Electricals
# 15   United States   Shipments Index Machinery & Electricals
# 18           World                      Price of Base Metals
# 20           World               Price of Metals  & Minerals
# 23           World                           Price of Copper
# 24   United States                                EUR in LCU
# 25   United States                      Electrical equipment
# 26  United Kingdom                      Electrical equipment
# 28          France                      Electrical equipment
# 29         Germany                      Electrical equipment
# 33     Switzerland            Machinery and equipment n.e.c.
# 40           World                      Electrical equipment
# 41     Switzerland                      Electrical equipment
#
#              Index Code
# 0        MAB_ELE_PRO156
# 1        MAB_ELE_SHP156
# 10       MAB_ELE_PRO756
# 11       MAB_ELE_SHP756
# 13       MAB_ELE_SHP826
# 15       MAB_ELE_SHP840
# 18  RohiBASEMET1000_org
# 20   RohiMETMIN1000_org
# 23    RohCOPPER1000_org
# 24       WKLWEUR840_org
# 25         PRI27840_org
# 26         PRI27826_org
# 28         PRI27250_org
# 29         PRI27276_org
# 33         PRO28756_org
# 40        PRO271000_org
# 41         PRO27756_org

# %%
selected_dt_features_12 = select_features_decision_tree(
    sales_df=sales_agg12,
    market_df=df_market,
    product_group=12,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 12:
# MAB_ELE_SHP826            0.557463
# PRO28826_org              0.262438
# MAB_ELE_SHP156            0.072532
# PRO27840_org              0.035436
# RohCRUDE_PETRO1000_org    0.031494
# MAB_ELE_SHP250            0.029329
# dtype: float64

# %% [markdown]
# # Product Group 13

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_13, selected_features_13 = plot_cross_correlation(
    sales_df=sales_agg13,
    market_df=df_market,
    product_group=13,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_13)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %%
selected_dt_features_13 = select_features_decision_tree(
    sales_df=sales_agg13,
    market_df=df_market,
    product_group=13,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 13:
# PRI27840_org      0.495388
# PRO27392_org      0.208195
# MAB_ELE_SHP392    0.107702
# PRO28392_org      0.072374
# MAB_ELE_SHP380    0.050324
# PRI27826_org      0.040246
# MAB_ELE_PRO156    0.020475
# dtype: float64

# %% [markdown]
# # Product Group 14

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_14, selected_features_14 = plot_cross_correlation(
    sales_df=sales_agg14,
    market_df=df_market,
    product_group=14,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_14)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %%
selected_dt_features_14 = select_features_decision_tree(
    sales_df=sales_agg14,
    market_df=df_market,
    product_group=14,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 14:
# PRI27840_org      0.649793
# MAB_ELE_PRO380    0.186532
# MAB_ELE_PRO392    0.068537
# WKLWEUR840_org    0.045776
# PRO28380_org      0.030277
# PRO27250_org      0.019087
# dtype: float64

# %% [markdown]
# # Product Group 16

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_16, selected_features_16 = plot_cross_correlation(
    sales_df=sales_agg16,
    market_df=df_market,
    product_group=16,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO756', 'MAB_ELE_SHP756', 'MAB_ELE_SHP826', 'PRI27826_org', 'PRO28756_org', 'PRO27756_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_16)]

filtered_info_market
# Out:
#             Region                                Index Name      Index Code
# 10     Switzerland  Production Index Machinery & Electricals  MAB_ELE_PRO756
# 11     Switzerland   Shipments Index Machinery & Electricals  MAB_ELE_SHP756
# 13  United Kingdom   Shipments Index Machinery & Electricals  MAB_ELE_SHP826
# 26  United Kingdom                      Electrical equipment    PRI27826_org
# 33     Switzerland            Machinery and equipment n.e.c.    PRO28756_org
# 41     Switzerland                      Electrical equipment    PRO27756_org

# %%
selected_dt_features_16 = select_features_decision_tree(
    sales_df=sales_agg16,
    market_df=df_market,
    product_group=16,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 16:
# PRO28276_org    0.821274
# PRO28826_org    0.153635
# PRI27276_org    0.025091
# dtype: float64

# %% [markdown]
# # Product Group 20

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_20, selected_features_20 = plot_cross_correlation(
    sales_df=sales_agg20,
    market_df=df_market,
    product_group=20,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO826', 'PRO28826_org', 'PRO27276_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_20)]

filtered_info_market
# Out:
#             Region                                Index Name      Index Code
# 12  United Kingdom  Production Index Machinery & Electricals  MAB_ELE_PRO826
# 34  United Kingdom            Machinery and equipment n.e.c.    PRO28826_org
# 46         Germany                      Electrical equipment    PRO27276_org

# %%
selected_dt_features_20 = select_features_decision_tree(
    sales_df=sales_agg20,
    market_df=df_market,
    product_group=20,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 20:
# PRO27756_org          0.246853
# PRO27276_org          0.182701
# PRO28840_org          0.175949
# MAB_ELE_SHP756        0.171472
# MAB_ELE_PRO826        0.141927
# MAB_ELE_PRO756        0.051387
# RohiNATGAS1000_org    0.011047
# dtype: float64

# %% [markdown]
# # Product Group 36

# %% [markdown]
# ## Feature selection

# %%
relevant_corr_36, selected_features_36 = plot_cross_correlation(
    sales_df=sales_agg36,
    market_df=df_market,
    product_group=36,
    max_lag=6,
    threshold=0.4
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_36)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %%
selected_dt_features_36 = select_features_decision_tree(
    sales_df=sales_agg36,
    market_df=df_market,
    product_group=36,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 36:
# PRO28840_org      0.596555
# PRI27156_org      0.211093
# MAB_ELE_PRO840    0.157040
# MAB_ELE_SHP276    0.016780
# MAB_ELE_SHP756    0.013931
# dtype: float64

# %% [markdown]
# # Export

# %%
selected_feature_goup = list(set(selected_features_1 + selected_features_3 + selected_features_4 + selected_features_5 + selected_features_6 + selected_features_8 + selected_features_9 + selected_features_11 + selected_features_12 + selected_features_13 + selected_features_14 + selected_features_16 + selected_features_20 + selected_features_36))
print(len(selected_feature_goup))

filtered_info_market = info_market[info_market['Index Code'].isin(selected_feature_goup)]

filtered_info_market
# Out:
# 40
#             Region                                Index Name  \
# 0            China  Production Index Machinery & Electricals
# 1            China   Shipments Index Machinery & Electricals
# 2           France  Production Index Machinery & Electricals
# 3           France   Shipments Index Machinery & Electricals
# 4          Germany  Production Index Machinery & Electricals
# 5          Germany   Shipments Index Machinery & Electricals
# 7            Italy   Shipments Index Machinery & Electricals
# 8            Japan  Production Index Machinery & Electricals
# 9            Japan   Shipments Index Machinery & Electricals
# 10     Switzerland  Production Index Machinery & Electricals
# 11     Switzerland   Shipments Index Machinery & Electricals
# 12  United Kingdom  Production Index Machinery & Electricals
# 13  United Kingdom   Shipments Index Machinery & Electricals
# 15   United States   Shipments Index Machinery & Electricals
# 17          Europe   Shipments Index Machinery & Electricals
# 18           World                      Price of Base Metals
# 19           World                           Price of Energy
# 20           World               Price of Metals  & Minerals
# 21           World                Price of Natural gas index
# 22           World               Price of Crude oil, average
# 23           World                           Price of Copper
# 24   United States                                EUR in LCU
# 25   United States                      Electrical equipment
# 26  United Kingdom                      Electrical equipment
# 27           Italy                      Electrical equipment
# 28          France                      Electrical equipment
# 29         Germany                      Electrical equipment
# 30           China                      Electrical equipment
# 31   United States            Machinery and equipment n.e.c.
# 32           World            Machinery and equipment n.e.c.
# 33     Switzerland            Machinery and equipment n.e.c.
# 34  United Kingdom            Machinery and equipment n.e.c.
# 36           Japan            Machinery and equipment n.e.c.
# 37          France            Machinery and equipment n.e.c.
# 38         Germany            Machinery and equipment n.e.c.
# 40           World                      Electrical equipment
# 41     Switzerland                      Electrical equipment
# 42  United Kingdom                      Electrical equipment
# 44           Japan                      Electrical equipment
# 46         Germany                      Electrical equipment
#
#                 Index Code
# 0           MAB_ELE_PRO156
# 1           MAB_ELE_SHP156
# 2           MAB_ELE_PRO250
# 3           MAB_ELE_SHP250
# 4           MAB_ELE_PRO276
# 5           MAB_ELE_SHP276
# 7           MAB_ELE_SHP380
# 8           MAB_ELE_PRO392
# 9           MAB_ELE_SHP392
# 10          MAB_ELE_PRO756
# 11          MAB_ELE_SHP756
# 12          MAB_ELE_PRO826
# 13          MAB_ELE_SHP826
# 15          MAB_ELE_SHP840
# 17         MAB_ELE_SHP1100
# 18     RohiBASEMET1000_org
# 19      RohiENERGY1000_org
# 20      RohiMETMIN1000_org
# 21      RohiNATGAS1000_org
# 22  RohCRUDE_PETRO1000_org
# 23       RohCOPPER1000_org
# 24          WKLWEUR840_org
# 25            PRI27840_org
# 26            PRI27826_org
# 27            PRI27380_org
# 28            PRI27250_org
# 29            PRI27276_org
# 30            PRI27156_org
# 31            PRO28840_org
# 32           PRO281000_org
# 33            PRO28756_org
# 34            PRO28826_org
# 36            PRO28392_org
# 37            PRO28250_org
# 38            PRO28276_org
# 40           PRO271000_org
# 41            PRO27756_org
# 42            PRO27826_org
# 44            PRO27392_org
# 46            PRO27276_org
