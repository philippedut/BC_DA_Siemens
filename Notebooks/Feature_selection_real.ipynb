# %% [markdown]
# # **BUSINESS CASE 2: SIEMENS ADVANTA SALES FORECASTING**
#
#
# ## 🎓 Master’s Program in Data Science & Advanced Analytics
# **Nova IMS** | March 2025
# **Course:** Business Cases with Data Science
#
# ## 👥 Team **Group A**
# - **Alice Viegas** | 20240572
# - **Bernardo Faria** | 20240579
# - **Dinis Pinto** | 20240612
# - **Daan van Holten** | 20240681
# - **Philippe Dutranoit** | 20240518

# %% [markdown]
# ## 📊 Goal of the notebook
#
# this notebook focuses on feature selection

# %% [markdown]
#  #  Initial setup and modules/packages loading

# %%
# Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler

from Functions import *

from Feature_selection_Functions import (
    plot_cross_correlation,
    select_features_decision_tree,
)


import importlib
imported_module = importlib.import_module("Feature_selection_Functions")
importlib.reload(imported_module)
# Out:
# <module 'Feature_selection_Functions' from '/Users/philippedutranoit/document_ordi/nova/business_case_for_data_sciense/cases/BC_DA_Siemens/Notebooks/Feature_selection_Functions.py'>

# %% [markdown]
# # Importing Data

# %%
df_market = pd.read_csv("../Data/df_market.csv")
info_market = pd.read_csv("../Data/info_market.csv")

sales_agg1 = pd.read_csv("../Data/sales_agg1.csv")
sales_agg3 = pd.read_csv("../Data/sales_agg3.csv")
sales_agg4 = pd.read_csv("../Data/sales_agg4.csv")
sales_agg5 = pd.read_csv("../Data/sales_agg5.csv")
sales_agg6 = pd.read_csv("../Data/sales_agg6.csv")
sales_agg8 = pd.read_csv("../Data/sales_agg8.csv")
sales_agg9 = pd.read_csv("../Data/sales_agg9.csv")
sales_agg11 = pd.read_csv("../Data/sales_agg11.csv")
sales_agg12 = pd.read_csv("../Data/sales_agg12.csv")
sales_agg13 = pd.read_csv("../Data/sales_agg13.csv")
sales_agg14 = pd.read_csv("../Data/sales_agg14.csv")
sales_agg16 = pd.read_csv("../Data/sales_agg16.csv")
sales_agg20 = pd.read_csv("../Data/sales_agg20.csv")
sales_agg36 = pd.read_csv("../Data/sales_agg36.csv")

# %% [markdown]
# # **Step 1** Feature selection **step 1** using cross correlation

# %% [markdown]
# In this first step, the goal is to check for cross-correlation to determine if lagged market features correlate with sales. This step is performed to reduce the number of features for the next step of feature selection.
# - The maximum lag is set to 6, meaning we only look at the 6 months prior, as we assume that business reactions to "market_data" are relatively fast.
# - The correlation threshold is set to 0.5, as we aim to capture a somewhat strong correlation between the variables.

# %% [markdown]
# ## Product Group 1

# %%
relevant_corr_1, selected_features_1 = plot_cross_correlation(
    sales_df=sales_agg1,
    market_df=df_market,
    product_group=1,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_1)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 3

# %%
relevant_corr_3, selected_features_3 = plot_cross_correlation(
    sales_df=sales_agg3,
    market_df=df_market,
    product_group=3,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_3)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 4

# %%
relevant_corr_4, selected_features_4 = plot_cross_correlation(
    sales_df=sales_agg4,
    market_df=df_market,
    product_group=4,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_4)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 5

# %%
relevant_corr_5, selected_features_5 = plot_cross_correlation(
    sales_df=sales_agg5,
    market_df=df_market,
    product_group=5,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_SHP250']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_5)]

filtered_info_market
# Out:
#    Region                               Index Name      Index Code
# 3  France  Shipments Index Machinery & Electricals  MAB_ELE_SHP250

# %% [markdown]
# ## Product Group 6

# %%
relevant_corr_6, selected_features_6 = plot_cross_correlation(
    sales_df=sales_agg6,
    market_df=df_market,
    product_group=6,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_6)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 8

# %%
relevant_corr_8, selected_features_8 = plot_cross_correlation(
    sales_df=sales_agg8,
    market_df=df_market,
    product_group=8,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO156', 'MAB_ELE_SHP156', 'MAB_ELE_SHP840', 'RohiBASEMET1000_org', 'RohiMETMIN1000_org', 'RohiNATGAS1000_org', 'RohCOPPER1000_org', 'WKLWEUR840_org', 'PRI27840_org', 'PRI27826_org', 'PRI27380_org', 'PRI27250_org', 'PRI27276_org', 'PRO271000_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_8)]

filtered_info_market
# Out:
#             Region                                Index Name  \
# 0            China  Production Index Machinery & Electricals
# 1            China   Shipments Index Machinery & Electricals
# 15   United States   Shipments Index Machinery & Electricals
# 18           World                      Price of Base Metals
# 20           World               Price of Metals  & Minerals
# 21           World                Price of Natural gas index
# 23           World                           Price of Copper
# 24   United States                                EUR in LCU
# 25   United States                      Electrical equipment
# 26  United Kingdom                      Electrical equipment
# 27           Italy                      Electrical equipment
# 28          France                      Electrical equipment
# 29         Germany                      Electrical equipment
# 40           World                      Electrical equipment
#
#              Index Code
# 0        MAB_ELE_PRO156
# 1        MAB_ELE_SHP156
# 15       MAB_ELE_SHP840
# 18  RohiBASEMET1000_org
# 20   RohiMETMIN1000_org
# 21   RohiNATGAS1000_org
# 23    RohCOPPER1000_org
# 24       WKLWEUR840_org
# 25         PRI27840_org
# 26         PRI27826_org
# 27         PRI27380_org
# 28         PRI27250_org
# 29         PRI27276_org
# 40        PRO271000_org

# %% [markdown]
# ## Product Group 9

# %%
relevant_corr_9, selected_features_9 = plot_cross_correlation(
    sales_df=sales_agg9,
    market_df=df_market,
    product_group=9,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_9)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 11

# %%
relevant_corr_11, selected_features_11 = plot_cross_correlation(
    sales_df=sales_agg11,
    market_df=df_market,
    product_group=11,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO392', 'MAB_ELE_SHP392', 'PRO28392_org', 'PRO27392_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_11)]

filtered_info_market
# Out:
#    Region                                Index Name      Index Code
# 8   Japan  Production Index Machinery & Electricals  MAB_ELE_PRO392
# 9   Japan   Shipments Index Machinery & Electricals  MAB_ELE_SHP392
# 36  Japan            Machinery and equipment n.e.c.    PRO28392_org
# 44  Japan                      Electrical equipment    PRO27392_org

# %% [markdown]
# ## Product Group 12

# %%
relevant_corr_12, selected_features_12 = plot_cross_correlation(
    sales_df=sales_agg12,
    market_df=df_market,
    product_group=12,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO156', 'MAB_ELE_SHP156', 'MAB_ELE_SHP840', 'RohiMETMIN1000_org', 'RohCOPPER1000_org', 'PRI27826_org', 'PRI27250_org', 'PRO271000_org', 'PRO27756_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_12)]

filtered_info_market
# Out:
#             Region                                Index Name  \
# 0            China  Production Index Machinery & Electricals
# 1            China   Shipments Index Machinery & Electricals
# 15   United States   Shipments Index Machinery & Electricals
# 20           World               Price of Metals  & Minerals
# 23           World                           Price of Copper
# 26  United Kingdom                      Electrical equipment
# 28          France                      Electrical equipment
# 40           World                      Electrical equipment
# 41     Switzerland                      Electrical equipment
#
#             Index Code
# 0       MAB_ELE_PRO156
# 1       MAB_ELE_SHP156
# 15      MAB_ELE_SHP840
# 20  RohiMETMIN1000_org
# 23   RohCOPPER1000_org
# 26        PRI27826_org
# 28        PRI27250_org
# 40       PRO271000_org
# 41        PRO27756_org

# %% [markdown]
# ## Product Group 13

# %%
relevant_corr_13, selected_features_13 = plot_cross_correlation(
    sales_df=sales_agg13,
    market_df=df_market,
    product_group=13,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_13)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 14

# %%
relevant_corr_14, selected_features_14 = plot_cross_correlation(
    sales_df=sales_agg14,
    market_df=df_market,
    product_group=14,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_14)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 16

# %%
relevant_corr_16, selected_features_16 = plot_cross_correlation(
    sales_df=sales_agg16,
    market_df=df_market,
    product_group=16,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# ['MAB_ELE_PRO756', 'MAB_ELE_SHP826', 'PRO28756_org']

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_16)]

filtered_info_market
# Out:
#             Region                                Index Name      Index Code
# 10     Switzerland  Production Index Machinery & Electricals  MAB_ELE_PRO756
# 13  United Kingdom   Shipments Index Machinery & Electricals  MAB_ELE_SHP826
# 33     Switzerland            Machinery and equipment n.e.c.    PRO28756_org

# %% [markdown]
# ## Product Group 20

# %%
relevant_corr_20, selected_features_20 = plot_cross_correlation(
    sales_df=sales_agg20,
    market_df=df_market,
    product_group=20,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_20)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## Product Group 36

# %%
relevant_corr_36, selected_features_36 = plot_cross_correlation(
    sales_df=sales_agg36,
    market_df=df_market,
    product_group=36,
    max_lag=6,
    threshold=0.5
)
# Out:
# Selected Features for Product Group:
# []

# %%
filtered_info_market = info_market[info_market['Index Code'].isin(selected_features_36)]

filtered_info_market
# Out:
# Empty DataFrame
# Columns: [Region, Index Name, Index Code]
# Index: []

# %% [markdown]
# ## aggregating the results

# %%
selected_feature_goup = list(set(selected_features_1 + selected_features_3 + selected_features_4 + selected_features_5 + selected_features_6 + selected_features_8 + selected_features_9 + selected_features_11 + selected_features_12 + selected_features_13 + selected_features_14 + selected_features_16 + selected_features_20 + selected_features_36))
print(len(selected_feature_goup))

filtered_info_market = info_market[info_market['Index Code'].isin(selected_feature_goup)]

filtered_info_market
# Out:
# 23
#             Region                                Index Name  \
# 0            China  Production Index Machinery & Electricals
# 1            China   Shipments Index Machinery & Electricals
# 3           France   Shipments Index Machinery & Electricals
# 8            Japan  Production Index Machinery & Electricals
# 9            Japan   Shipments Index Machinery & Electricals
# 10     Switzerland  Production Index Machinery & Electricals
# 13  United Kingdom   Shipments Index Machinery & Electricals
# 15   United States   Shipments Index Machinery & Electricals
# 18           World                      Price of Base Metals
# 20           World               Price of Metals  & Minerals
# 21           World                Price of Natural gas index
# 23           World                           Price of Copper
# 24   United States                                EUR in LCU
# 25   United States                      Electrical equipment
# 26  United Kingdom                      Electrical equipment
# 27           Italy                      Electrical equipment
# 28          France                      Electrical equipment
# 29         Germany                      Electrical equipment
# 33     Switzerland            Machinery and equipment n.e.c.
# 36           Japan            Machinery and equipment n.e.c.
# 40           World                      Electrical equipment
# 41     Switzerland                      Electrical equipment
# 44           Japan                      Electrical equipment
#
#              Index Code
# 0        MAB_ELE_PRO156
# 1        MAB_ELE_SHP156
# 3        MAB_ELE_SHP250
# 8        MAB_ELE_PRO392
# 9        MAB_ELE_SHP392
# 10       MAB_ELE_PRO756
# 13       MAB_ELE_SHP826
# 15       MAB_ELE_SHP840
# 18  RohiBASEMET1000_org
# 20   RohiMETMIN1000_org
# 21   RohiNATGAS1000_org
# 23    RohCOPPER1000_org
# 24       WKLWEUR840_org
# 25         PRI27840_org
# 26         PRI27826_org
# 27         PRI27380_org
# 28         PRI27250_org
# 29         PRI27276_org
# 33         PRO28756_org
# 36         PRO28392_org
# 40        PRO271000_org
# 41         PRO27756_org
# 44         PRO27392_org

# %% [markdown]
# # **Step 2** Feature slection using decision tree

# %% [markdown]
# In this step, we aim to minimize the set of features included in the model to avoid noise. This step helps us identify the relevant lags for the model and properly define the market data required for prediction to build the models effectively.

# %% [markdown]
# ## preparation

# %%
def create_lag_features(df, max_lag):
    """
    Adds lag features for all original columns in the DataFrame from lag 1 to max_lag.

    Parameters:
    df (pd.DataFrame): Input DataFrame. Must contain a 'date' column.
    max_lag (int): Maximum lag value to generate features for.

    Returns:
    pd.DataFrame: DataFrame with new lag features.
    """
    df = df.copy()
    df.set_index('date', inplace=True)

    original_cols = df.columns.tolist()  # Store original column names

    for lag in range(1, max_lag + 1):
        for col in original_cols:
            df[f'{col}_lag_{lag}'] = df[col].shift(lag)

    df.reset_index(inplace=True)
    return df

# %%
selected_feature_goup
df_market_reduced = df_market[['date'] + selected_feature_goup]
df_market_reduced.head()
df_market_reduced = create_lag_features(df_market_reduced, 6)
df_market_reduced.head()
# Out:
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# /var/folders/z6/_vn8cndd4x5dmx2cpjfdkjdr0000gn/T/ipykernel_47271/842538311.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.reset_index(inplace=True)
#          date  WKLWEUR840_org  MAB_ELE_PRO756  MAB_ELE_SHP840  MAB_ELE_SHP156  \
# 0  2004-02-01          1.2646       86.074496       90.442749       16.940704
# 1  2004-03-01          1.2262       86.038258       90.580357       23.711852
# 2  2004-04-01          1.1985       85.997063       90.751805       24.435235
# 3  2004-05-01          1.2007       85.951483       90.961426       23.708115
# 4  2004-06-01          1.2138       85.902640       91.213203       27.009138
#
#    RohiBASEMET1000_org  MAB_ELE_PRO392  PRI27380_org  PRI27826_org  \
# 0            54.039811      109.334010     93.020027     81.056482
# 1            54.666162      140.884616     93.540268     81.089738
# 2            54.872715      105.853579     93.852425     81.130304
# 3            51.230356      101.864777     93.852425     81.178845
# 4            52.876331      120.332920     93.956467     81.235936
#
#    PRO271000_org  ...  RohiNATGAS1000_org_lag_6  MAB_ELE_PRO156_lag_6  \
# 0      91.390440  ...                       NaN                   NaN
# 1      91.511498  ...                       NaN                   NaN
# 2      91.666790  ...                       NaN                   NaN
# 3      91.861457  ...                       NaN                   NaN
# 4      92.100289  ...                       NaN                   NaN
#
#    MAB_ELE_SHP392_lag_6  PRI27840_org_lag_6  PRO27756_org_lag_6  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
#
#    PRI27276_org_lag_6  RohCOPPER1000_org_lag_6  PRO28392_org_lag_6  \
# 0                 NaN                      NaN                 NaN
# 1                 NaN                      NaN                 NaN
# 2                 NaN                      NaN                 NaN
# 3                 NaN                      NaN                 NaN
# 4                 NaN                      NaN                 NaN
#
#    MAB_ELE_SHP826_lag_6  RohiMETMIN1000_org_lag_6
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
#
# [5 rows x 162 columns]

# %% [markdown]
# ## Product 1

# %%
selected_dt_features_1 = select_features_decision_tree(
    sales_df=sales_agg1,
    market_df=df_market_reduced,
    product_group=1,
    importance_threshold=0.01,
    max_depth=4
)
# Out:
# Selected features for Product Group 1:
# PRO27756_org_lag_6      0.732663
# MAB_ELE_SHP250_lag_4    0.110150
# MAB_ELE_SHP156          0.085448
# PRI27380_org_lag_1      0.063578
# dtype: float64
